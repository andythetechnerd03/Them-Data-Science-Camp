# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('new.csv')
df
# Out:
#              sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  \
# 0        1000001   3.6     5.00        4.0     NaN      NaN       NaN
# 1        1000002   8.4     6.75        7.6     NaN      NaN       NaN
# 2        1000003   5.8     7.50        5.0     NaN      NaN       NaN
# 3        1000004   7.4     7.50        8.6     NaN      NaN       NaN
# 4        1000005   7.2     8.50        9.0     NaN      NaN       NaN
# ...          ...   ...      ...        ...     ...      ...       ...
# 995436  64006584   8.4     6.75        4.6     NaN      NaN       NaN
# 995437  64006585   5.6     6.50        2.8     NaN      NaN       NaN
# 995438  64006586   5.8     6.00        6.6     NaN      NaN       NaN
# 995439  64006587   7.6     6.75        7.0     NaN      NaN       NaN
# 995440  64006588   6.6     4.50        3.2     NaN      NaN       NaN
#
#         lich_su  dia_li  gdcd           hoi_dong  ma_tinh
# 0          2.75    6.00  8.75     Sở GDĐT Hà Nội        1
# ...

# %%
#df['sum'] = df['toan'] + df['ngu_van'] + df['ngoai_ngu'] + df['vat_li']+ df['hoa_hoc'] + df['lich_su'] + df['dia_li'] + df['gdcd']
#df['avg'] = df['sum']/6
#df['do_dai_hoc'] = (df['sum'] > 45) & (df['avg'] > 8)
#df.to_csv("new.csv")

# %%
df
# Out:
#              sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  \
# 0        1000001   3.6     5.00        4.0     NaN      NaN       NaN
# 1        1000002   8.4     6.75        7.6     NaN      NaN       NaN
# 2        1000003   5.8     7.50        5.0     NaN      NaN       NaN
# 3        1000004   7.4     7.50        8.6     NaN      NaN       NaN
# 4        1000005   7.2     8.50        9.0     NaN      NaN       NaN
# ...          ...   ...      ...        ...     ...      ...       ...
# 995436  64006584   8.4     6.75        4.6     NaN      NaN       NaN
# 995437  64006585   5.6     6.50        2.8     NaN      NaN       NaN
# 995438  64006586   5.8     6.00        6.6     NaN      NaN       NaN
# 995439  64006587   7.6     6.75        7.0     NaN      NaN       NaN
# 995440  64006588   6.6     4.50        3.2     NaN      NaN       NaN
#
#         lich_su  dia_li  gdcd           hoi_dong  ma_tinh
# 0          2.75    6.00  8.75     Sở GDĐT Hà Nội        1
# ...

# %%
df['avg'] = df[['toan','ngu_van','ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su','dia_li','gdcd']].mean(skipna=True, axis=1)
df
# Out:
#              sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  \
# 0        1000001   3.6     5.00        4.0     NaN      NaN       NaN
# 1        1000002   8.4     6.75        7.6     NaN      NaN       NaN
# 2        1000003   5.8     7.50        5.0     NaN      NaN       NaN
# 3        1000004   7.4     7.50        8.6     NaN      NaN       NaN
# 4        1000005   7.2     8.50        9.0     NaN      NaN       NaN
# ...          ...   ...      ...        ...     ...      ...       ...
# 995436  64006584   8.4     6.75        4.6     NaN      NaN       NaN
# 995437  64006585   5.6     6.50        2.8     NaN      NaN       NaN
# 995438  64006586   5.8     6.00        6.6     NaN      NaN       NaN
# 995439  64006587   7.6     6.75        7.0     NaN      NaN       NaN
# 995440  64006588   6.6     4.50        3.2     NaN      NaN       NaN
#
#         lich_su  dia_li  gdcd           hoi_dong  ma_tinh       avg
# ...

# %%
group = df.groupby(['ma_tinh','hoi_dong'])['avg'].mean().reset_index(name='Avg score')
group
# Out:
#     ma_tinh                 hoi_dong  Avg score
# 0         1           Sở GDĐT Hà Nội   6.504821
# 1         2  Sở GDĐT TP. Hồ Chí Minh   6.521004
# 2         3        Sở GDĐT Hải Phòng   6.908472
# 3         4          Sở GDĐT Đà Nẵng   6.166126
# 4         5         Sở GDĐT Hà Giang   5.409836
# ..      ...                      ...        ...
# 58       60      Sở GD-KHCN Bạc Liêu   6.558116
# 59       61           Sở GDĐT Cà Mau   6.113274
# 60       62        Sở GDĐT Điện Biên   6.101239
# 61       63         Sở GDĐT Đăk Nông   5.800606
# 62       64        Sở GDĐT Hậu Giang   5.973309
#
# [63 rows x 3 columns]

# %%
group.to_csv('test.csv')

# %%
df2 = pd.read_csv("test.csv")
df2['hoi_dong'].replace("Sở GDĐT ","",regex=True,inplace=True)
df2['hoi_dong'].replace("Sở GD-KHCN ","",regex=True,inplace=True)
df2
# Out:
#     Unnamed: 0  ma_tinh         hoi_dong  Avg score
# 0            0        1           Hà Nội   6.504821
# 1            1        2  TP. Hồ Chí Minh   6.521004
# 2            2        3        Hải Phòng   6.908472
# 3            3        4          Đà Nẵng   6.166126
# 4            4        5         Hà Giang   5.409836
# ..         ...      ...              ...        ...
# 58          58       60         Bạc Liêu   6.558116
# 59          59       61           Cà Mau   6.113274
# 60          60       62        Điện Biên   6.101239
# 61          61       63         Đăk Nông   5.800606
# 62          62       64        Hậu Giang   5.973309
#
# [63 rows x 4 columns]

# %%
df2 = df2.sort_values('Avg score', ascending=False)
df2.reset_index
df2
# Out:
#     Unnamed: 0  ma_tinh            hoi_dong  Avg score
# 15          15       16   Sở GDĐT Vĩnh Phúc   6.954082
# 23          23       25    Sở GDĐT Nam Định   6.948303
# 25          25       27   Sở GDĐT Ninh Bình   6.938236
# 42          42       44  Sở GDĐT Bình Dương   6.937562
# 2            2        3   Sở GDĐT Hải Phòng   6.908472
# ..         ...      ...                 ...        ...
# 37          37       39     Sở GDĐT Phú Yên   5.879358
# 56          56       58    Sở GDĐT Trà Vinh   5.863037
# 38          38       40     Sở GDĐT Đắk Lắk   5.806131
# 61          61       63    Sở GDĐT Đăk Nông   5.800606
# 4            4        5    Sở GDĐT Hà Giang   5.409836
#
# [63 rows x 4 columns]

# %%
sns.boxplot(data=df2,x="Avg score")
# Out:
# <AxesSubplot:xlabel='Avg score'>

# %%
df2.to_csv("test1.csv")

# %%
X = df[['toan','ngu_van','ngoai_ngu']]
Y = df['do_dai_hoc']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'do_dai_hoc'
#
# ...

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

print("number of test samples:", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples: 298633
# number of training samples: 696808

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr_model = LogisticRegression()
lr_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
df3 = df.groupby(["hoi_dong","ma_tinh"])['value']

# %%
predict = lr_model.predict(x_test)

# %%
accuracy_score(predict, y_test)
# Out:
# 0.9650440507244679

# %%
print("Intercept:", lr_model.intercept_)
print("Parameters:", lr_model.coef_)
# Out:
# Intercept: [-22.8405698]
# Parameters: [[0.26685544 1.67480605 0.72096951]]
